# %%
import geopandas as gpd
import plotly.express as px

# %%
gdf = gpd.read_file(r'C:\Users\GSE1\Beca\3813283 - PT Services and Infrastructure SSBC - Documents\Technical - Working Files\Data\Bus stops\BusStopAudit_20210617.csv')

# %%
gdf.head()
# Out:
#                              _GHDglobalid _Inspection sheet link      X_Value
# 0  {52C3C954-6279-4770-BA11-F19E18838ED8}  Click for asset sheet  1883662.765  \
# 1  {DF2B2736-8613-493E-A9F3-6B78A1C88E50}  Click for asset sheet  1892585.275
# 2  {BB94C81E-DEAD-4613-9757-F60FA88B24A9}  Click for asset sheet  1893592.689
# 3  {EF3FDCE1-5D7A-4773-BEE6-42CBE314D038}  Click for asset sheet   1889605.85
# 4  {7A43FE0D-6414-4C09-900D-1FB97AED1939}  Click for asset sheet  1876354.999
#
#        Y_Value                          Coordinate System Map_ID  _ID
# 0  5825923.781  NZGD_2000_New_Zealand_Transverse_Mercator      1  567  \
# 1  5821237.525  NZGD_2000_New_Zealand_Transverse_Mercator      2  382
# 2  5820787.888  NZGD_2000_New_Zealand_Transverse_Mercator      3  376
# 3  5822642.185  NZGD_2000_New_Zealand_Transverse_Mercator      4  560
# 4  5823910.914  NZGD_2000_New_Zealand_Transverse_Mercator      5  300
#
# ...

# %%
fig = px.bar(gdf, x="SHELTER")
fig.show()

# %%
gdf.to_file('gdf.shp')
# Out:
# C:\Users\GSE1\AppData\Local\Temp\ipykernel_18928\338146108.py:1: UserWarning:
#
# Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.

# %%
gpd.read_file(r'C:\Users\GSE1\Downloads\gdf.shp')
# Out:
#                                  _GHDglobal             _Inspectio
# 0    {52C3C954-6279-4770-BA11-F19E18838ED8}  Click for asset sheet  \
# 1    {DF2B2736-8613-493E-A9F3-6B78A1C88E50}  Click for asset sheet
# 2    {BB94C81E-DEAD-4613-9757-F60FA88B24A9}  Click for asset sheet
# 3    {EF3FDCE1-5D7A-4773-BEE6-42CBE314D038}  Click for asset sheet
# 4    {7A43FE0D-6414-4C09-900D-1FB97AED1939}  Click for asset sheet
# ..                                      ...                    ...
# 858  {FFD529E3-004C-463E-9296-1C25524A4800}  Click for asset sheet
# 859  {06C14554-7B4B-46E4-B3D4-217B6A6C25FB}  Click for asset sheet
# 860  {FD422D20-39A4-4AC8-95AA-6621E5EE2C75}  Click for asset sheet
# 861  {44F23F5E-3A84-420A-A440-ADE39383BDD5}  Click for asset sheet
# 862  {65911EFC-C59E-468E-81C3-EDA7C0EA0B16}  Click for asset sheet
#
#          X_Value      Y_Value                                 Coordinate
# 0    1883662.765  5825923.781  NZGD_2000_New_Zealand_Transverse_Mercator  \
# ...
