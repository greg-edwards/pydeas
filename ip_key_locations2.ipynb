# %%
# libraries

import osmnx as ox
import geopandas as gpd
import folium
import pandas as pd

# %%
#extract Tuaranga road geometries

G = ox.graph_from_place("Tauranga City, New Zealand", network_type='drive')

# %%
#import data

hybrid_services = gpd.read_file(r"C:\Users\GSE1\Beca\3813283 - PT Services and Infrastructure SSBC - Documents\Technical - Working Files\01 SSBC\05 Shortlist\01 Service options assessment\hybrid_services.geojson")
pt_demand = gpd.read_file(r'C:\Users\GSE1\Beca\3813283 - PT Services and Infrastructure SSBC - Documents\Technical - Working Files\01 SSBC\05 Shortlist\01 Service options assessment\pt_trip_2048.csv')
los_links_am = gpd.read_file(r'\\Beca.net\projects\381\3813283\4-TTR\Modelling\Outputs\Shapefiles_18Aug2023\LOS_Toll_AM_Links_2048DN_TTM22_NoSB.shp', geometry="geometry")
los_nodes_am = gpd.read_file(r'\\Beca.net\projects\381\3813283\4-TTR\Modelling\Outputs\Shapefiles_18Aug2023\LOS_Toll_AM_Nodes_2048DN_TTM22_NoSB.shp', geometry="geometry")

# %%
#set crs
los_links_am.set_crs('epsg:2193', inplace=True)
los_nodes_am.set_crs('epsg:2193', inplace=True)
pt_demand.set_crs('epsg:2193', inplace=True)
hybrid_services.set_crs('epsg:2193', inplace=True, allow_override=True)
# Out:
#                                          full_name      dir_id dir_name
# 0                            L1 Katikati - inbound  1190326853  inbound  \
# 1        G St Andrews - Bellevue - Matua - inbound  1190326845  inbound
# 2                    H Te Puke - Papamoa - inbound  1190326849  inbound
# 3                            K Crosstown - inbound  1190326837  inbound
# 4   A Mt Maunganui - City - Tauriko West - inbound  1190326829  inbound
# 5          E Ohauiti - City - Brookfield - inbound  1190326843  inbound
# 6             C Pyes Pa - City - Papamoa - inbound  1190326835  inbound
# 7               A3 - The Lakes - Pyes Pa - inbound  1190326858  inbound
# 8          BX Te Tumu - City - Bethlehem - inbound  1190326831  inbound
# 9                   L Omokoroa - Airport - inbound  1190326851  inbound
# 10      G1 Bethlehem - Tauranga Crossing - inbound  1190326847  inbound
# 11                          F Beachfront - inbound  1190326833  inbound
# 12      D Welcome Bay - City - Bethlehem - inbound  1190326841  inbound
#
#    pattern   line_id                             line_name line_color
# 0        A  053149d3                           L1 Katikati    #eab0c5  \
# 1        A  176f4493       G St Andrews - Bellevue - Matua    #066A40
# 2        A  27855025                   H Te Puke - Papamoa    #f67010
# 3        A  2fcb37de                           K Crosstown    #f5a200
# 4        A  524d2831  A Mt Maunganui - City - Tauriko West    #007DBD
# 5        A  78680d25         E Ohauiti - City - Brookfield    #de1c1c
# 6        A  8bb30649            C Pyes Pa - City - Papamoa    #A72051
# 7        A  8f5ecd01              A3 - The Lakes - Pyes Pa    #2ba1db
# 8        A  91d95ca8         BX Te Tumu - City - Bethlehem    #C9500E
# 9        A  a2093885                  L Omokoroa - Airport    #a8647d
# 10       A  aacd468f      G1 Bethlehem - Tauranga Crossing    #2dad78
# 11       A  c56c2241                          F Beachfront    #5A8400
# 12       A  cad900d2      D Welcome Bay - City - Bethlehem    #613FA6
#
#       map_id                 map_name
# 0   18b88c2d  Hybrid Network 2048 1.1  \
# 1   18b88c2d  Hybrid Network 2048 1.1
# 2   18b88c2d  Hybrid Network 2048 1.1
# 3   18b88c2d  Hybrid Network 2048 1.1
# 4   18b88c2d  Hybrid Network 2048 1.1
# 5   18b88c2d  Hybrid Network 2048 1.1
# 6   18b88c2d  Hybrid Network 2048 1.1
# 7   18b88c2d  Hybrid Network 2048 1.1
# 8   18b88c2d  Hybrid Network 2048 1.1
# 9   18b88c2d  Hybrid Network 2048 1.1
# 10  18b88c2d  Hybrid Network 2048 1.1
# 11  18b88c2d  Hybrid Network 2048 1.1
# 12  18b88c2d  Hybrid Network 2048 1.1
#
#                                                   url      km     hours_year
# 0   https://platform.remix.com/project/10ce5503/li...  21.949    9493.458333  \
# 1   https://platform.remix.com/project/10ce5503/li...  16.059   25389.375000
# 2   https://platform.remix.com/project/10ce5503/li...  16.721   14056.166667
# 3   https://platform.remix.com/project/10ce5503/li...  21.245   54479.700000
# 4   https://platform.remix.com/project/10ce5503/li...  23.646   78770.450000
# 5   https://platform.remix.com/project/10ce5503/li...  23.524   35206.600000
# 6   https://platform.remix.com/project/10ce5503/li...  27.531   92177.616667
# 7   https://platform.remix.com/project/10ce5503/li...  12.059   18618.875000
# 8   https://platform.remix.com/project/10ce5503/li...  39.880  120332.666667
# 9   https://platform.remix.com/project/10ce5503/li...  29.923   50440.225000
# 10  https://platform.remix.com/project/10ce5503/li...   8.160    9967.100000
# 11  https://platform.remix.com/project/10ce5503/li...  27.901   92509.450000
# 12  https://platform.remix.com/project/10ce5503/li...  27.534   90166.541667
#
#        cost_year vehicle_ty  vehicle_co  minheadway  maxheadway     minkph
# 0   9.493458e+05        Bus           3          30          30  47.953091  \
# 1   2.538938e+06        Bus           6          15          15  24.100000
# 2   1.405617e+06        Bus           4          20          20  36.420000
# 3   5.447970e+06        Bus          12          10          10  24.100000
# 4   7.877045e+06        Bus          18           7           7  24.100000
# 5   3.520660e+06        Bus           8          15          15  24.100000
# 6   9.217762e+06        Bus          21           7           7  24.100000
# 7   1.861888e+06        Bus           5          15          15  26.526316
# 8   1.203327e+07        Bus          27           7           7  26.423667
# 9   5.044022e+06        Bus          11          15          15  24.100000
# 10  9.967100e+05        Bus           3          20          20  24.100000
# 11  9.250945e+06        Bus          21           7           7  24.100000
# 12  9.016654e+06        Bus          20           7           7  24.100000
#
#        maxkph                                           geometry
# 0   47.953091  MULTILINESTRING ((19584790.898 -4514392.804, 1...
# 1   24.100000  MULTILINESTRING ((19604602.428 -4536359.755, 1...
# 2   36.420000  MULTILINESTRING ((19628631.853 -4549196.486, 1...
# 3   24.100000  MULTILINESTRING ((19602639.865 -4544612.638, 1...
# 4   24.100000  MULTILINESTRING ((19600725.170 -4544378.923, 1...
# 5   24.100000  MULTILINESTRING ((19608943.888 -4541611.345, 1...
# 6   24.100000  MULTILINESTRING ((19623933.057 -4537336.137, 1...
# 7   26.526316  MULTILINESTRING ((19603834.323 -4542671.272, 1...
# 8   26.423667  MULTILINESTRING ((19638049.259 -4544011.184, 1...
# 9   24.100000  MULTILINESTRING ((19598084.672 -4527690.285, 1...
# 10  24.100000  MULTILINESTRING ((19603834.323 -4542671.272, 1...
# 11  24.100000  MULTILINESTRING ((19638043.873 -4544008.110, 1...
# 12  24.100000  MULTILINESTRING ((19614624.522 -4543179.455, 1...

# %%
#create geodataframe of all road geometries in Tauranga

gdf = ox.graph_to_gdfs(G, nodes=False, edges=True)

# %%
gdf.head()
# Out:
#                                                        osmid   lanes
# u         v          key
# 247014753 7397434438 0                             657538168       2  \
#           4866204635 0    [701547512, 461219596, 1107883893]  [2, 1]
# 247014899 247014903  0                [1103106292, 27212758]  [1, 3]
#           1597355601 0                             146443707       2
# 247014903 298632431  0                             392378544     NaN
#
#                                        name    highway maxspeed  oneway
# u         v          key
# 247014753 7397434438 0      Te Puke Highway  secondary      100   False  \
#           4866204635 0                  NaN  secondary       70    True
# 247014899 247014903  0    State Highway 29A      trunk       50    True
#           1597355601 0    State Highway 29A      trunk      100   False
# 247014903 298632431  0                  NaN      trunk       50    True
#
#                          reversed    length
# u         v          key
# 247014753 7397434438 0       True   585.773  \
#           4866204635 0      False   123.800
# 247014899 247014903  0      False   349.942
#           1597355601 0       True  1351.773
# 247014903 298632431  0      False    12.105
#
#                                                                    geometry
# u         v          key
# 247014753 7397434438 0    LINESTRING (176.28407 -37.71666, 176.28416 -37...  \
#           4866204635 0    LINESTRING (176.28407 -37.71666, 176.28393 -37...
# 247014899 247014903  0    LINESTRING (176.17417 -37.72352, 176.17384 -37...
#           1597355601 0    LINESTRING (176.17417 -37.72352, 176.17432 -37...
# 247014903 298632431  0    LINESTRING (176.17059 -37.72473, 176.17046 -37...
#
#                              ref bridge  junction width area access
# u         v          key
# 247014753 7397434438 0       NaN    NaN       NaN   NaN  NaN    NaN
#           4866204635 0       NaN    NaN       NaN   NaN  NaN    NaN
# 247014899 247014903  0    SH 29A    NaN       NaN   NaN  NaN    NaN
#           1597355601 0    SH 29A    NaN       NaN   NaN  NaN    NaN
# 247014903 298632431  0    SH 29A    yes  circular   NaN  NaN    NaN

# %%
#drop na values from gdf column'lanes', set CRS

gdf_drop = gdf.dropna(subset=['lanes'])
gdf_drop.head()
gdf_drop.set_crs('epsg:2193', inplace=True, allow_override=True)
# Out:
# C:\Users\GSE1\.conda\envs\ox\Lib\site-packages\geopandas\geodataframe.py:1443: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
#                                                           osmid   lanes
# u           v           key
# 247014753   7397434438  0                             657538168       2  \
#             4866204635  0    [701547512, 461219596, 1107883893]  [2, 1]
# 247014899   247014903   0                [1103106292, 27212758]  [1, 3]
#             1597355601  0                             146443707       2
# 247014956   3777941155  0                             374405015       3
# ...                                                         ...     ...
# 10235183745 9499693321  0                             755863781       1
# 10235183746 10235183752 0                             755863780       1
# 10235183752 7059762011  0                             755863780       1
# 10235183753 10235183745 0                             755863781       1
# 10235226142 10145438695 0                            1119121977       2
#
#                                           name    highway maxspeed  oneway
# u           v           key
# 247014753   7397434438  0      Te Puke Highway  secondary      100   False  \
#             4866204635  0                  NaN  secondary       70    True
# 247014899   247014903   0    State Highway 29A      trunk       50    True
#             1597355601  0    State Highway 29A      trunk      100   False
# 247014956   3777941155  0    State Highway 29A      trunk       50    True
# ...                                        ...        ...      ...     ...
# 10235183745 9499693321  0      Te Okuroa Drive  secondary       50    True
# 10235183746 10235183752 0      Te Okuroa Drive  secondary       50    True
# 10235183752 7059762011  0      Te Okuroa Drive  secondary       50    True
# 10235183753 10235183745 0      Te Okuroa Drive  secondary       50    True
# 10235226142 10145438695 0      Taurikura Drive  secondary      NaN    True
#
#                             reversed    length
# u           v           key
# 247014753   7397434438  0       True   585.773  \
#             4866204635  0      False   123.800
# 247014899   247014903   0      False   349.942
#             1597355601  0       True  1351.773
# 247014956   3777941155  0      False    38.873
# ...                              ...       ...
# 10235183745 9499693321  0      False   171.369
# 10235183746 10235183752 0      False     8.612
# 10235183752 7059762011  0      False    24.754
# 10235183753 10235183745 0      False     8.458
# 10235226142 10145438695 0      False    26.442
#
#                                                                       geometry
# u           v           key
# 247014753   7397434438  0    LINESTRING (176.284 -37.717, 176.284 -37.717, ...  \
#             4866204635  0    LINESTRING (176.284 -37.717, 176.284 -37.717, ...
# 247014899   247014903   0    LINESTRING (176.174 -37.724, 176.174 -37.724, ...
#             1597355601  0    LINESTRING (176.174 -37.724, 176.174 -37.723, ...
# 247014956   3777941155  0    LINESTRING (176.168 -37.727, 176.168 -37.727, ...
# ...                                                                        ...
# 10235183745 9499693321  0    LINESTRING (176.348 -37.731, 176.347 -37.731, ...
# 10235183746 10235183752 0        LINESTRING (176.348 -37.731, 176.348 -37.731)
# 10235183752 7059762011  0        LINESTRING (176.348 -37.731, 176.348 -37.731)
# 10235183753 10235183745 0        LINESTRING (176.348 -37.731, 176.348 -37.731)
# 10235226142 10145438695 0    LINESTRING (176.087 -37.756, 176.087 -37.756, ...
#
#                                 ref bridge junction width area access
# u           v           key
# 247014753   7397434438  0       NaN    NaN      NaN   NaN  NaN    NaN
#             4866204635  0       NaN    NaN      NaN   NaN  NaN    NaN
# 247014899   247014903   0    SH 29A    NaN      NaN   NaN  NaN    NaN
#             1597355601  0    SH 29A    NaN      NaN   NaN  NaN    NaN
# 247014956   3777941155  0    SH 29A    NaN      NaN   NaN  NaN    NaN
# ...                             ...    ...      ...   ...  ...    ...
# 10235183745 9499693321  0       NaN    NaN      NaN   NaN  NaN    NaN
# 10235183746 10235183752 0       NaN    NaN      NaN   NaN  NaN    NaN
# 10235183752 7059762011  0       NaN    NaN      NaN   NaN  NaN    NaN
# 10235183753 10235183745 0       NaN    NaN      NaN   NaN  NaN    NaN
# 10235226142 10145438695 0       NaN    NaN      NaN   NaN  NaN    NaN
#
# [3089 rows x 15 columns]

# %%
# filter by lanes and include 'oneway' only

two_lane = gdf_drop.loc[(gdf_drop['lanes']=='2')&(gdf_drop['oneway']=='True')]
three_lane = gdf_drop.loc[(gdf_drop['lanes']=='3')&(gdf_drop['oneway']=='True')] 
four_lane = gdf_drop.loc[(gdf_drop['lanes']=='4')&(gdf_drop['oneway']=='True')] 
five_lane = gdf_drop.loc[(gdf_drop['lanes']=='5')&(gdf_drop['oneway']=='True')]

# %%
# filter junctions

junction_circular = gdf_drop.loc[(gdf_drop['junction']=='circular')]
junction_roundabout = gdf_drop.loc[(gdf_drop['junction']=='roundabout')]

# %%
# filter by segment length: bus lane=0-25m,BRT=500m+, Busway=500m+ 

bus_lane = gdf_drop.loc[(gdf_drop['lanes']=='2')|(gdf_drop['lanes']=="['3','2']")&(gdf_drop['oneway']==True)]
brt = gdf_drop.loc[(gdf_drop['lanes']=='2')&(gdf_drop['oneway']==True)&(gdf_drop['length']>=500)]
busway = gdf_drop.loc[(gdf_drop['lanes']=='3')&(gdf_drop['oneway']==True)&(gdf_drop['length']>=500)]

# %%
#pt demand - drop all columns except PT and geometry. Set CRS

pt_demand = pt_demand.loc[:, ['ADT_PUBLIC', 'ADT_PT', 'AM_PT', 'IP_PT', 'PM_PT', 'geometry']]

# %%
pt_demand.columns
# Out:
# Index(['ADT_PUBLIC', 'ADT_PT', 'AM_PT', 'IP_PT', 'PM_PT', 'geometry'], dtype='object')

# %%
# change data types of columns to float

pt_demand[['ADT_PUBLIC', 'ADT_PT', 'AM_PT', 'IP_PT', 'PM_PT']] = pt_demand[['ADT_PUBLIC', 'ADT_PT', 'AM_PT', 'IP_PT', 'PM_PT']].astype(float)

# %%
# Create equal-sized bins of AM PT demand and create new column
pt_demand['PT_BIN'] = pd.cut(pt_demand['AM_PT'], bins=5, labels=False)

# %%
pt_demand['AM_PT'].describe()
# Out:
# count    5610.000000
# mean       21.936649
# std        51.931386
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%        15.727500
# max       432.620000
# Name: AM_PT, dtype: float64

# %%
hybrid_services['vehicle_co'].describe()
# Out:
# count    13.000000
# mean     12.230769
# std       8.237656
# min       3.000000
# 25%       5.000000
# 50%      11.000000
# 75%      20.000000
# max      27.000000
# Name: vehicle_co, dtype: float64

# %%
# only show links with demand higher than 75th percentile

high_pt = pt_demand.loc[(pt_demand['AM_PT']>16)]

# %%
high_vehicle = hybrid_services.loc[(hybrid_services['vehicle_co']>=20)]

# %%
high_vehicle.to_crs(2193, inplace=False)
# Out:
#                                      full_name      dir_id dir_name pattern
# 6         C Pyes Pa - City - Papamoa - inbound  1190326835  inbound       A  \
# 8      BX Te Tumu - City - Bethlehem - inbound  1190326831  inbound       A
# 11                      F Beachfront - inbound  1190326833  inbound       A
# 12  D Welcome Bay - City - Bethlehem - inbound  1190326841  inbound       A
#
#      line_id                         line_name line_color    map_id
# 6   8bb30649        C Pyes Pa - City - Papamoa    #A72051  18b88c2d  \
# 8   91d95ca8     BX Te Tumu - City - Bethlehem    #C9500E  18b88c2d
# 11  c56c2241                      F Beachfront    #5A8400  18b88c2d
# 12  cad900d2  D Welcome Bay - City - Bethlehem    #613FA6  18b88c2d
#
#                    map_name
# 6   Hybrid Network 2048 1.1  \
# 8   Hybrid Network 2048 1.1
# 11  Hybrid Network 2048 1.1
# 12  Hybrid Network 2048 1.1
#
#                                                   url      km     hours_year
# 6   https://platform.remix.com/project/10ce5503/li...  27.531   92177.616667  \
# 8   https://platform.remix.com/project/10ce5503/li...  39.880  120332.666667
# 11  https://platform.remix.com/project/10ce5503/li...  27.901   92509.450000
# 12  https://platform.remix.com/project/10ce5503/li...  27.534   90166.541667
#
#        cost_year vehicle_ty  vehicle_co  minheadway  maxheadway     minkph
# 6   9.217762e+06        Bus          21           7           7  24.100000  \
# 8   1.203327e+07        Bus          27           7           7  26.423667
# 11  9.250945e+06        Bus          21           7           7  24.100000
# 12  9.016654e+06        Bus          20           7           7  24.100000
#
#        maxkph                                           geometry
# 6   24.100000  MULTILINESTRING ((19623933.057 -4537336.137, 1...
# 8   26.423667  MULTILINESTRING ((19638049.259 -4544011.184, 1...
# 11  24.100000  MULTILINESTRING ((19638043.873 -4544008.110, 1...
# 12  24.100000  MULTILINESTRING ((19614624.522 -4543179.455, 1...

# %%
high_vehicle.crs
# Out:
# <Projected CRS: EPSG:2193>
# Name: NZGD2000 / New Zealand Transverse Mercator 2000
# Axis Info [cartesian]:
# - N[north]: Northing (metre)
# - E[east]: Easting (metre)
# Area of Use:
# - name: New Zealand - North Island, South Island, Stewart Island - onshore.
# - bounds: (166.37, -47.33, 178.63, -34.1)
# Coordinate Operation:
# - name: New Zealand Transverse Mercator 2000
# - method: Transverse Mercator
# Datum: New Zealand Geodetic Datum 2000
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
high_pt_bin = pt_demand.loc[(pt_demand['PT_BIN']>=1)]

# %%
los_nodes_am.columns
# Out:
# Index(['N', 'DELAY_MAX', 'LOS_MAX', 'DELAY_WAVG', 'LOS_WAVG', 'SECTOR', 'X',
#        'Y', 'LOCATION', 'LABEL', 'FAREZONE', 'geometry'],
#       dtype='object')

# %%
low_los_nodes = los_nodes_am.loc[(los_nodes_am['LOS_WAVG']>=3)]
low_los_links = los_links_am.loc[(los_links_am['LOS']>=3)]

# %%
# Folium map

m = high_pt_bin.explore(column="AM_PT",
    tiles="CartoDB positron",
    tooltip="AM_PT",
    highlight=True,
    name='AM peak PT Demand',
    k=5,
    popup=['AM_PT'])

buses = high_vehicle.explore(
    m=m,
    column="vehicle_co",
    tooltip="line_name",
    name="Hybrid Network Bus Routes",
    highlight=True)


los_nodes = low_los_nodes.explore(
    m=m,
    column="LOS_WAVG",
    tooltip="LOS_WAVG",
    name="LOS Nodes (AM)",
    highlight=True,
    marker_type="circle_marker",
    marker_kwds={
        "radius" : "6"})

los_links = low_los_links.explore(
    m=m,
    column="LOS",
    tooltip="LOS",
    name="LOS Links (AM)",
    highlight=True,)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_552df401af245bd25070fad874e07ddb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_552df401af245bd25070fad874e07ddb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_552df401af245bd25070fad874e07ddb = L.map(
#                 &quot;map_552df401af245bd25070fad874e07ddb&quot;,
#                 {
#                     center: [-37.7038009143443, 176.18933938789615],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_552df401af245bd25070fad874e07ddb);
#
#
#
#
#
#             var tile_layer_c9d5a9ebefae54ca0bd4ba7a0484172e = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_552df401af245bd25070fad874e07ddb);
#
#
#             map_552df401af245bd25070fad874e07ddb.fitBounds(
#                 [[-37.74995110757546, 176.01391318862454], [-37.657650721113136, 176.3647655871678]],
#                 {}
#             );
#
#
#         function geo_json_ede2330fbc515e66ab02571942f43c02_styler(feature) {
#             switch(feature.id) {
#                 case &quot;697&quot;: case &quot;773&quot;: case &quot;1066&quot;: case &quot;1130&quot;: case &quot;1184&quot;: case &quot;1734&quot;: case &quot;1797&quot;: case &quot;1965&quot;: case &quot;3091&quot;: case &quot;3522&quot;: case &quot;3525&quot;: case &quot;4778&quot;: case &quot;4781&quot;:
#                     return {&quot;color&quot;: &quot;#424086&quot;, &quot;fillColor&quot;: &quot;#424086&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;699&quot;: case &quot;777&quot;: case &quot;778&quot;: case &quot;988&quot;: case &quot;1138&quot;: case &quot;1169&quot;: case &quot;2101&quot;: case &quot;2194&quot;: case &quot;2256&quot;: case &quot;2695&quot;: case &quot;2985&quot;: case &quot;3140&quot;: case &quot;3577&quot;: case &quot;4294&quot;: case &quot;4296&quot;: case &quot;4299&quot;:

# %%
pt_priority_intersection = high_pt_bin.overlay(low_los_nodes, how='intersection', keep_geom_type=False)

# %%
pt_priority_intersection.head()
# Out:
#    ADT_PUBLIC     ADT_PT   AM_PT  IP_PT  PM_PT  PT_BIN     N  DELAY_MAX
# 0   360.85474  551.50476  151.92  27.14  19.70       1   988      309.0  \
# 1   353.31174  654.24176  103.59  50.30  33.23       1   988      309.0
# 2   360.85474  665.80475  170.43  38.18  19.70       1   988      309.0
# 3   353.31174  654.24176  103.59  50.30  33.23       1  5020       42.0
# 4   399.92841  625.57843  132.92  41.12  24.72       1  5020       42.0
#
#    LOS_MAX  DELAY_WAVG  LOS_WAVG  SECTOR          X          Y  LOCATION
# 0        6   270.17313         6       0  1873882.0  5819037.0         0  \
# 1        6   270.17313         6       0  1873882.0  5819037.0         0
# 2        6   270.17313         6       0  1873882.0  5819037.0         0
# 3        4    35.06447         4       0  1873881.0  5818662.0         0
# 4        4    35.06447         4       0  1873881.0  5818662.0         0
#
#     LABEL  FAREZONE                         geometry
# 0    SH29         2  POINT (1873882.000 5819037.000)
# 1    SH29         2  POINT (1873882.000 5819037.000)
# 2    SH29         2  POINT (1873882.000 5819037.000)
# 3  pyespa         2  POINT (1873881.000 5818662.000)
# 4  pyespa         2  POINT (1873881.000 5818662.000)

# %%
# rank nodes based on demand

pt_priority_intersection['rank'] = pt_priority_intersection['AM_PT'].rank(method="average", ascending=True).astype('int')

# %%
pt_priority_intersection.head()
# Out:
#    ADT_PUBLIC     ADT_PT   AM_PT  IP_PT  PM_PT  PT_BIN     N  DELAY_MAX
# 0   360.85474  551.50476  151.92  27.14  19.70       1   988      309.0  \
# 1   353.31174  654.24176  103.59  50.30  33.23       1   988      309.0
# 2   360.85474  665.80475  170.43  38.18  19.70       1   988      309.0
# 3   353.31174  654.24176  103.59  50.30  33.23       1  5020       42.0
# 4   399.92841  625.57843  132.92  41.12  24.72       1  5020       42.0
#
#    LOS_MAX  DELAY_WAVG  LOS_WAVG  SECTOR          X          Y  LOCATION
# 0        6   270.17313         6       0  1873882.0  5819037.0         0  \
# 1        6   270.17313         6       0  1873882.0  5819037.0         0
# 2        6   270.17313         6       0  1873882.0  5819037.0         0
# 3        4    35.06447         4       0  1873881.0  5818662.0         0
# 4        4    35.06447         4       0  1873881.0  5818662.0         0
#
#     LABEL  FAREZONE                         geometry  rank
# 0    SH29         2  POINT (1873882.000 5819037.000)   101
# 1    SH29         2  POINT (1873882.000 5819037.000)    33
# 2    SH29         2  POINT (1873882.000 5819037.000)   112
# 3  pyespa         2  POINT (1873881.000 5818662.000)    33
# 4  pyespa         2  POINT (1873881.000 5818662.000)    83

# %%
#identify links where there is high PT demand and high number of buses

links_merged = high_pt_bin.sjoin(high_vehicle, how="left")

# %%
pt_priority_links = low_los_links.overlay(links_merged, how='intersection', keep_geom_type=True)

# %%
pt_priority_links['rank'] = pt_priority_links['AM_PT'].rank(method="average", ascending=True).astype('int')

# %%
pt_priority_intersection.shape
# Out:
# (191, 19)

# %%
pt_priority_intersection.geometry.name
# Out:
# 'geometry'

# %%
pt_priority_intersection.shape
# Out:
# (191, 19)

# %%
pt_priority_intersection.loc[pt_priority_intersection.duplicated(subset=['geometry'])]
# Out:
#      ADT_PUBLIC     ADT_PT   AM_PT  IP_PT  PM_PT  PT_BIN     N  DELAY_MAX
# 1     353.31174  654.24176  103.59  50.30  33.23       1   988      309.0  \
# 2     360.85474  665.80475  170.43  38.18  19.70       1   988      309.0
# 4     399.92841  625.57843  132.92  41.12  24.72       1  5020       42.0
# 5     360.85474  665.80475  170.43  38.18  19.70       1  5020       42.0
# 6     400.10373  619.83374  114.61  41.52  34.91       1  5020       42.0
# ..          ...        ...     ...    ...    ...     ...   ...        ...
# 183   499.83120  499.83120   99.99  28.30  35.57       1  4035       57.6
# 186   221.08028  350.16028  120.22  12.43   7.63       1  2498       38.4
# 188   550.32013  550.32013   88.64  36.26  41.52       1  2859       36.0
# 189   548.47028  548.47028  113.07  32.25  33.49       1  2859       36.0
# 190   550.32013  550.32013   88.64  36.26  41.52       1  2859       36.0
#
#      LOS_MAX  DELAY_WAVG  LOS_WAVG  SECTOR          X          Y  LOCATION
# 1          6   270.17313         6       0  1873882.0  5819037.0         0  \
# 2          6   270.17313         6       0  1873882.0  5819037.0         0
# 4          4    35.06447         4       0  1873881.0  5818662.0         0
# 5          4    35.06447         4       0  1873881.0  5818662.0         0
# 6          4    35.06447         4       0  1873881.0  5818662.0         0
# ..       ...         ...       ...     ...        ...        ...       ...
# 183        5    28.09412         3       0  1895645.0  5818781.0         0
# 186        4    29.99994         3       0  1872844.0  5818478.0         0
# 188        4    22.32254         3       0  1895345.0  5818931.0         0
# 189        4    22.32254         3       0  1895345.0  5818931.0         0
# 190        4    22.32254         3       0  1895345.0  5818931.0         0
#
#                  LABEL  FAREZONE                         geometry  rank
# 1                 SH29         2  POINT (1873882.000 5819037.000)    33
# 2                 SH29         2  POINT (1873882.000 5819037.000)   112
# 4               pyespa         2  POINT (1873881.000 5818662.000)    83
# 5               pyespa         2  POINT (1873881.000 5818662.000)   112
# 6               pyespa         2  POINT (1873881.000 5818662.000)    58
# ..                 ...       ...                              ...   ...
# 183                  0         2  POINT (1895645.000 5818781.000)    26
# 186  TTM21_Forecasting         2  POINT (1872844.000 5818478.000)    67
# 188            Papamoa         2  POINT (1895345.000 5818931.000)     3
# 189            Papamoa         2  POINT (1895345.000 5818931.000)    48
# 190            Papamoa         2  POINT (1895345.000 5818931.000)     3
#
# [132 rows x 19 columns]

# %%
pt_priority_intersection.drop_duplicates(subset='geometry', keep='first', inplace=True)

# %%
pt_priority_intersection.shape
# Out:
# (59, 19)

# %%
pt_priority_links.shape
# Out:
# (446, 99)

# %%
pt_priority_links.loc[pt_priority_links.duplicated(subset='geometry')]
# Out:
#         A     B  FREIGHTLANE  BUSLANE  BL_IP  GRADIENT  FSFACTOR  DISTANCE
# 4     988  1031            0        0      0         0         0   0.02377  \
# 5    1031   988            0        0      0         0         0   0.02377
# 10   1031  5023            0        0      0         0         0   0.07500
# 11   5023  1031            0        0      0         0         0   0.07500
# 20   5022  5023            0        0      0         0         0   0.09000
# ..    ...   ...          ...      ...    ...       ...       ...       ...
# 428  2939  2801            0        0      0         0         0   0.18890
# 431  2862  2802            0        0      0         0         0   0.47011
# 432  2802  2939            0        0      0         0         0   0.56035
# 439  4036  2859            0        0      0         0         0   0.14318
# 440  4035  4036            0        0      0         0         0   0.19235
#
#      LINKTYPE  JURISDICT  ...  hours_year cost_year  vehicle_ty  vehicle_co
# 4           6          2  ...         NaN       NaN         NaN         NaN  \
# 5           6          2  ...         NaN       NaN         NaN         NaN
# 10          8          2  ...         NaN       NaN         NaN         NaN
# 11          8          2  ...         NaN       NaN         NaN         NaN
# 20          8          0  ...         NaN       NaN         NaN         NaN
# ..        ...        ...  ...         ...       ...         ...         ...
# 428         5          2  ...         NaN       NaN         NaN         NaN
# 431         2          2  ...         NaN       NaN         NaN         NaN
# 432         5          2  ...         NaN       NaN         NaN         NaN
# 439         0          0  ...         NaN       NaN         NaN         NaN
# 440         0          0  ...         NaN       NaN         NaN         NaN
#
#      minheadway maxheadway  minkph  maxkph
# 4           NaN        NaN     NaN     NaN  \
# 5           NaN        NaN     NaN     NaN
# 10          NaN        NaN     NaN     NaN
# 11          NaN        NaN     NaN     NaN
# 20          NaN        NaN     NaN     NaN
# ..          ...        ...     ...     ...
# 428         NaN        NaN     NaN     NaN
# 431         NaN        NaN     NaN     NaN
# 432         NaN        NaN     NaN     NaN
# 439         NaN        NaN     NaN     NaN
# 440         NaN        NaN     NaN     NaN
#
#                                               geometry  rank
# 4    LINESTRING (1873882.000 5819037.000, 1873888.0...   280
# 5    LINESTRING (1873888.000 5819014.000, 1873882.0...   280
# 10   LINESTRING (1873888.000 5819014.000, 1873909.0...   280
# 11   LINESTRING (1873909.000 5818942.000, 1873888.0...   280
# 20   LINESTRING (1873918.000 5818851.000, 1873909.0...    87
# ..                                                 ...   ...
# 428  LINESTRING (1892079.000 5820562.000, 1891920.0...   160
# 431  LINESTRING (1892635.000 5819791.000, 1892225.0...   139
# 432  LINESTRING (1892225.000 5820021.000, 1892079.0...    39
# 439  LINESTRING (1895475.000 5818871.000, 1895345.0...    13
# 440  LINESTRING (1895645.000 5818781.000, 1895475.0...    59
#
# [124 rows x 99 columns]

# %%
pt_priority_links.drop_duplicates(subset='geometry', keep='first', inplace=True)

# %%
pt_priority_links.shape
# Out:
# (322, 99)

# %%
map = pt_priority_intersection.explore(tiles="CartoDB positron",
    tooltip=['AM_PT', 'LOS_WAVG', "rank"],
    highlight=True,
    name="Nodes",
    marker_type="circle_marker",
    marker_kwds={
        "radius" : "4",
        "fillColor":"red"},
    legend_kwds= {
        "caption" : "Nodes by rank (higher is greater priority)"
    },
    style_kwds={
        "stroke":False,
    })

links = pt_priority_links.explore(
    m=map,
    tooltip=["AM_PT", "LOS", "rank"],
    highlight=True,
    name="Links",
    legend_kwds= {
        "caption" : "Links by rank (higher is greater priority)"
    })

folium.LayerControl().add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aaf7b881e33095b86bb073767b63d487 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aaf7b881e33095b86bb073767b63d487&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aaf7b881e33095b86bb073767b63d487 = L.map(
#                 &quot;map_aaf7b881e33095b86bb073767b63d487&quot;,
#                 {
#                     center: [-37.70111477990587, 176.2238100738874],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_aaf7b881e33095b86bb073767b63d487);
#
#
#
#
#
#             var tile_layer_47412bd3bb65d93db4f26a563a153d25 = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_aaf7b881e33095b86bb073767b63d487);
#
#
#             map_aaf7b881e33095b86bb073767b63d487.fitBounds(
#                 [[-37.74034946062948, 176.09298703317745], [-37.66188009918226, 176.35463311459733]],
#                 {}
#             );
#
#
#         function geo_json_0b1e4719baf320f904a271321b07026e_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;stroke&quot;: false, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_0b1e4719baf320f904a271321b07026e_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_0b1e4719baf320f904a271321b07026e_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: &quot;4&quot;, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_0b1e4719baf320f904a271321b07026e_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_0b1e4719baf320f904a271321b07026e_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_0b1e4719baf320f904a271321b07026e.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_0b1e4719baf320f904a271321b07026e_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_0b1e4719baf320f904a271321b07026e = L.geoJson(null, {
#                 onEachFeature: geo_json_0b1e4719baf320f904a271321b07026e_onEachFeature,
#
#                 style: geo_json_0b1e4719baf320f904a271321b07026e_styler,
#                 pointToLayer: geo_json_0b1e4719baf320f904a271321b07026e_pointToLayer
#         });
#
#         function geo_json_0b1e4719baf320f904a271321b07026e_add (data) {
#             geo_json_0b1e4719baf320f904a271321b07026e
#                 .addData(data)
#                 .addTo(map_aaf7b881e33095b86bb073767b63d487);
#         }
#             geo_json_0b1e4719baf320f904a271321b07026e_add({&quot;bbox&quot;: [176.09298703317745, -37.74034946062948, 176.35463311459733, -37.661880
