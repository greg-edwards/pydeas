# %%
# import bus stop data from Bay of Plenty
import osmnx as ox

tags = {'highway':'tertiary'}
gdf = ox.geometries_from_place("Tauranga City, New Zealand", tags=tags)

gdf.head()
# Out:
#                         highway  \
# element_type osmid
# way          23053200  tertiary
#              23053201  tertiary
#              27106936  tertiary
#              27146406  tertiary
#              27212792  tertiary
#
#                                                                 geometry  \
# element_type osmid
# way          23053200  LINESTRING (176.17961 -37.63656, 176.17928 -37...
#              23053201  LINESTRING (176.18360 -37.63982, 176.18329 -37...
#              27106936  LINESTRING (176.14653 -37.71855, 176.14646 -37...
#              27146406  LINESTRING (176.12978 -37.73830, 176.12993 -37...
#              27212792  LINESTRING (176.15173 -37.73702, 176.15188 -37...
#
#                       traffic_calming  surface maxspeed:advisory  \
# element_type osmid
# way          23053200             NaN  asphalt               NaN
#              23053201             NaN    paved               NaN
#              27106936             NaN  asphalt               NaN
# ...

# %%
import leafmap

m = leafmap.Map(center=[20, 0], zoom=3, widescreen=True)
m.add_gdf(gdf, layer_name="New Plymouth Bus Routes")
m
# Out:
# C:\Users\GSE1\.conda\envs\ox\Lib\site-packages\ipywidgets\widgets\widget.py:501: DeprecationWarning: Passing unrecognized arguments to super(Map).__init__(widescreen=True).
# object.__init__() takes exactly one argument (the instance to initialize)
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   super().__init__(**kwargs)
# C:\Users\GSE1\.conda\envs\ox\Lib\site-packages\ipyleaflet\leaflet.py:2479: DeprecationWarning: add_control is deprecated, use add instead
#   warnings.warn("add_control is deprecated, use add instead", DeprecationWarning)
# C:\Users\GSE1\.conda\envs\ox\Lib\site-packages\ipyleaflet\leaflet.py:2479: DeprecationWarning: add_control is deprecated, use add instead
#   warnings.warn("add_control is deprecated, use add instead", DeprecationWarning)
# C:\Users\GSE1\.conda\envs\ox\Lib\site-packages\ipyleaflet\leaflet.py:2406: DeprecationWarning: add_layer is deprecated, use add instead
# ...

# %%
import geopandas as gpd

# %%
gdf.to_csv("highways_secondary.csv")
